# %%
import pandas as pd
import numpy as np
import os
import sys
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
path= r'D:\Python\Data'
data ='\SindhEducationStats.xlsx'
dataCsv='\SindhEducationStats.csv'

# %%
#df1 = pd.read_csv("sindh-education-stats.csv")

# %%
data
# Out:
# '\\SindhEducationStats.xlsx'

# %%
if os.path.isfile(path+data):
    df = pd.read_excel(path+data)
    df.to_csv(path+dataCsv)
    
else:
    print("File is converted")

# %%
df = pd.read_csv(path+dataCsv,low_memory=False,\
                         usecols=lambda c: not c.startswith('Unnamed:'),sep=',',thousands=',')

# %%
df.head()
# Out:
#   District Location School Type      Category Composition  Number  Population  \
# 0    Badin    Urban     Primary  INSTITUTIONS       TOTAL     168     1804516
# 1    Badin    Urban     Primary  INSTITUTIONS        MALE      30     1804516
# 2    Badin    Urban     Primary  INSTITUTIONS      FEMALE      27     1804516
# 3    Badin    Urban     Primary  INSTITUTIONS       MIXED     111     1804516
# 4    Badin    Urban     Primary     ENROLMENT       TOTAL   16446     1804516
#
#     No/100000
# 0    9.309976
# 1    1.662496
# 2    1.496246
# 3    6.151234
# 4  911.380115

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3480 entries, 0 to 3479
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   District     3480 non-null   object
#  1   Location     3480 non-null   object
#  2   School Type  3480 non-null   object
#  3   Category     3480 non-null   object
#  4   Composition  3480 non-null   object
#  5   Number       3480 non-null   int64
#  6   Population   3480 non-null   int64
#  7   No/100000    3480 non-null   float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 217.6+ KB

# %%
df.columns
# Out:
# Index(['District', 'Location', 'School Type', 'Category', 'Composition',
#        'Number', 'Population', 'No/100000'],
#       dtype='object')

# %%
df.drop(df[df['Composition'] == "TOTAL"].index, inplace = True)
df.drop(df[df['Location'] == "Total"].index, inplace = True)
df.pop("No/100000")
print(df)
df.head()
# Out:
#                  District Location       School Type        Category  \
# 1                   Badin    Urban           Primary    INSTITUTIONS
# 2                   Badin    Urban           Primary    INSTITUTIONS
# 3                   Badin    Urban           Primary    INSTITUTIONS
# 5                   Badin    Urban           Primary       ENROLMENT
# 6                   Badin    Urban           Primary       ENROLMENT
# ...                   ...      ...               ...             ...
# 3433  Shaheed Benazirabad    Rural  Higher secondary    INSTITUTIONS
# 3435  Shaheed Benazirabad    Rural  Higher secondary       ENROLMENT
# 3436  Shaheed Benazirabad    Rural  Higher secondary       ENROLMENT
# 3438  Shaheed Benazirabad    Rural  Higher secondary  TEACHING STAFF
# 3439  Shaheed Benazirabad    Rural  Higher secondary  TEACHING STAFF
#
#      Composition  Number  Population
# 1           MALE      30     1804516
# 2         FEMALE      27     1804516
# ...

# %%
df=df.replace(to_replace="MALE",value="1")
df=df.replace(to_replace="FEMALE",value="2")
df=df.replace(to_replace="MIXED",value="3")
# df=df.replace(to_replace="INSTITUTIONS",value="4")
# df=df.replace(to_replace="ENROLMENT",value="5")
# df=df.replace(to_replace="TEACHING STAFF",value="6")
df=df.replace(to_replace="Urban",value="7")
df=df.replace(to_replace="Rural",value="8")
# df=df.replace(to_replace="Badin",value="9")
# df=df.replace(to_replace="Dadu",value="10")
# df=df.replace(to_replace="Hyderabad",value="11")
# df=df.replace(to_replace="Thatta",value="12")
# df=df.replace(to_replace="Jamshoro",value="13")
# df=df.replace(to_replace="Matira",value="14")
# df=df.replace(to_replace="Tando Allah yar",value="15")
# df=df.replace(to_replace="Tando Muhammad Khan",value="16")
# df=df.replace(to_replace="Sujawal",value="17")
# df=df.replace(to_replace="Central Karachi",value="18")
# df=df.replace(to_replace="East Karachi",value="19")
# df=df.replace(to_replace="South Karachi",value="20")
# df=df.replace(to_replace="West Karchi",value="21")
# df=df.replace(to_replace="Malir Karachi",value="22")
# df=df.replace(to_replace="Korangi Karachi",value="23")
# df=df.replace(to_replace="Jacobad",value="24")
# df=df.replace(to_replace="Larkana",value="25")
# df=df.replace(to_replace="Shikarpur",value="26")
# df=df.replace(to_replace="Kashmore",value="27")
# df=df.replace(to_replace="Kamber Shahdadkot",value="28")
# df=df.replace(to_replace="Khairpur Mirs",value="29")
# df=df.replace(to_replace="Sukkhur",value="30")
# df=df.replace(to_replace="Ghotki",value="31")
# df=df.replace(to_replace="Mirpurkhaas",value="32")
# df=df.replace(to_replace="Tharparkar",value="33")
# df=df.replace(to_replace="Umerkot",value="34")
# df=df.replace(to_replace="Sanghar",value="35")
# df=df.replace(to_replace="Naushero Feroz",value="36")
# df=df.replace(to_replace="Shaheed Benazirabad",value="37")
# df=df.replace(to_replace="Primary",value="38")
# df=df.replace(to_replace="Middle",value="39")
# df=df.replace(to_replace="Secondary",value="40")
# df=df.replace(to_replace="Higher secondary",value="41")

print(df)
# Out:
#                  District Location       School Type        Category  \
# 1                   Badin        7           Primary    INSTITUTIONS
# 2                   Badin        7           Primary    INSTITUTIONS
# 3                   Badin        7           Primary    INSTITUTIONS
# 5                   Badin        7           Primary       ENROLMENT
# 6                   Badin        7           Primary       ENROLMENT
# ...                   ...      ...               ...             ...
# 3433  Shaheed Benazirabad        8  Higher secondary    INSTITUTIONS
# 3435  Shaheed Benazirabad        8  Higher secondary       ENROLMENT
# 3436  Shaheed Benazirabad        8  Higher secondary       ENROLMENT
# 3438  Shaheed Benazirabad        8  Higher secondary  TEACHING STAFF
# 3439  Shaheed Benazirabad        8  Higher secondary  TEACHING STAFF
#
#      Composition  Number  Population
# 1              1      30     1804516
# 2              2      27     1804516
# ...

# %%
#df = [["Number","Population"]]
df.head(10)
# Out:
#    District Location School Type        Category Composition  Number  \
# 1     Badin        7     Primary    INSTITUTIONS           1      30
# 2     Badin        7     Primary    INSTITUTIONS           2      27
# 3     Badin        7     Primary    INSTITUTIONS           3     111
# 5     Badin        7     Primary       ENROLMENT           1   10015
# 6     Badin        7     Primary       ENROLMENT           2    6431
# 8     Badin        7     Primary  TEACHING STAFF           1     382
# 9     Badin        7     Primary  TEACHING STAFF           2     168
# 11    Badin        7      Middle    INSTITUTIONS           1       3
# 12    Badin        7      Middle    INSTITUTIONS           2       2
# 13    Badin        7      Middle    INSTITUTIONS           3       5
#
#     Population
# 1      1804516
# 2      1804516
# 3      1804516
# 5      1804516
# 6      1804516
# 8      1804516
# 9      1804516
# 11     1804516
# 12     1804516
# 13     1804516

# %%
df.tail(10)
# Out:
#                  District Location       School Type        Category  \
# 3426  Shaheed Benazirabad        8         Secondary       ENROLMENT
# 3428  Shaheed Benazirabad        8         Secondary  TEACHING STAFF
# 3429  Shaheed Benazirabad        8         Secondary  TEACHING STAFF
# 3431  Shaheed Benazirabad        8  Higher secondary    INSTITUTIONS
# 3432  Shaheed Benazirabad        8  Higher secondary    INSTITUTIONS
# 3433  Shaheed Benazirabad        8  Higher secondary    INSTITUTIONS
# 3435  Shaheed Benazirabad        8  Higher secondary       ENROLMENT
# 3436  Shaheed Benazirabad        8  Higher secondary       ENROLMENT
# 3438  Shaheed Benazirabad        8  Higher secondary  TEACHING STAFF
# 3439  Shaheed Benazirabad        8  Higher secondary  TEACHING STAFF
#
#      Composition  Number  Population
# 3426           2    7119     1612847
# 3428           1     540     1612847
# 3429           2     224     1612847
# 3431           1       1     1612847
# ...

# %%
df.describe()
# Out:
#               Number    Population
# count    1624.000000  1.624000e+03
# mean     2723.089901  1.696594e+06
# std      9144.795083  7.414800e+05
# min         0.000000  6.772280e+05
# 25%         6.000000  1.073146e+06
# 50%        79.500000  1.612373e+06
# 75%      1071.000000  2.057057e+06
# max    111888.000000  3.914757e+06

# %%
df.nunique()
# Out:
# District        29
# Location         2
# School Type      4
# Category         3
# Composition      3
# Number         764
# Population      28
# dtype: int64

# %%
df.notnull()
# Out:
#       District  Location  School Type  Category  Composition  Number  \
# 1         True      True         True      True         True    True
# 2         True      True         True      True         True    True
# 3         True      True         True      True         True    True
# 5         True      True         True      True         True    True
# 6         True      True         True      True         True    True
# ...        ...       ...          ...       ...          ...     ...
# 3433      True      True         True      True         True    True
# 3435      True      True         True      True         True    True
# 3436      True      True         True      True         True    True
# 3438      True      True         True      True         True    True
# 3439      True      True         True      True         True    True
#
#       Population
# 1           True
# 2           True
# 3           True
# 5           True
# 6           True
# ...          ...
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df1 = df.groupby(['District','Category'],as_index=False)['Composition'].count()
df.head(5)
# Out:
#   District Location School Type      Category Composition  Number  Population
# 1    Badin        7     Primary  INSTITUTIONS           1      30     1804516
# 2    Badin        7     Primary  INSTITUTIONS           2      27     1804516
# 3    Badin        7     Primary  INSTITUTIONS           3     111     1804516
# 5    Badin        7     Primary     ENROLMENT           1   10015     1804516
# 6    Badin        7     Primary     ENROLMENT           2    6431     1804516

# %%
#df.columns = df.columns.str.lstrip()
#df.columns = df.columns.str.rstrip()
#df['Population'] = df['Population'].str.replace(',', '').astype(float)

# %%
df['Number'] = df['Number'].astype(float)
df['Population'] = df['Population'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1624 entries, 1 to 3439
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   District     1624 non-null   object
#  1   Location     1624 non-null   object
#  2   School Type  1624 non-null   object
#  3   Category     1624 non-null   object
#  4   Composition  1624 non-null   object
#  5   Number       1624 non-null   float64
#  6   Population   1624 non-null   float64
# dtypes: float64(2), object(5)
# memory usage: 101.5+ KB

# %%
df.head(5)
# Out:
#   District Location School Type      Category Composition   Number  Population
# 1    Badin        7     Primary  INSTITUTIONS           1     30.0   1804516.0
# 2    Badin        7     Primary  INSTITUTIONS           2     27.0   1804516.0
# 3    Badin        7     Primary  INSTITUTIONS           3    111.0   1804516.0
# 5    Badin        7     Primary     ENROLMENT           1  10015.0   1804516.0
# 6    Badin        7     Primary     ENROLMENT           2   6431.0   1804516.0

# %%
df2 = df.pivot_table(index=["District"],values="Number",columns=["School Type"],aggfunc="sum",margins=True,margins_name="Total").reset_index()
df2
# Out:
# School Type             District  Higher secondary    Middle    Primary  \
# 0                          Badin           12083.0   10988.0   147181.0
# 1                Central Karachi            7593.0   13807.0    43773.0
# 2                           Dadu           13493.0   12178.0   166544.0
# 3                   East Karachi            2659.0    2738.0    21397.0
# 4                         Ghotki           13332.0   12348.0   154243.0
# 5                      Hyderabad           22127.0   24450.0    75513.0
# 6                        Jacobad           13854.0   10114.0   104906.0
# 7                       Jamshoro           12257.0    6975.0    50444.0
# 8              Kamber Shahdadkot           12092.0    7346.0   142255.0
# 9                       Kashmore           17019.0    5885.0    87598.0
# 10                 Khairpur Mirs           27593.0   33376.0   221642.0
# 11               Korangi Karachi            3353.0    5141.0    30044.0
# ...

# %%
df1.corr()
# Out:
#              Composition
# Composition          1.0

# %%
plt.plot(df['Category'],df['Composition'])
plt.title("Category Vs GenderComposition")
plt.xlabel("Category")
plt.ylabel("GenderComposition")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.bar(df.Category,df.Composition)
plt.show()

# %%
plt.plot(df['Category'],df['Number'])
plt.title("Category Vs GenderComposition")
plt.xlabel("Category")
plt.ylabel("GenderComposition")
plt.show()

# %%
df1.corr()
# Out:
#              Composition
# Composition          1.0

# %%
import seaborn as sns

sns.heatmap(df.corr(), vmin=-1, vmax=1,
annot=True,cmap="rocket_r")
plt.show()

# %%
df.corr()
# Out:
#               Number  Population
# Number      1.000000    0.007989
# Population  0.007989    1.000000

# %%
#np.corrcoef(df["Number"], df["Population"])

# %%
#df["Number"].mean()

# %%
import scipy.stats as stats

# %%
df['Composition'].corr(df['Number']

# %%
df.corr()

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(df)

# %%
#What is correlation test? 
#The strength of the association between two variables is known as correlation test.

# %%
# Composition = {'MALE': 1, 'FEMALE': 2, 'MIXED': 3}
#Composition.df.sindh-education-stats.csv.unique()#
#print(df)

# %%
##Using drop() to delete rows based on column value
#df.drop(df[df['Fee'] >= 24000].index, inplace = True)
