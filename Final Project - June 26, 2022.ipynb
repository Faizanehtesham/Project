# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("sindh-education-stats.csv")

# %%
df = df1

# %%
df.head()
# Out:
#   District Location School Type      Category Composition   Number   \
# 0    Badin    Urban     Primary  INSTITUTIONS       TOTAL      168
# 1    Badin    Urban     Primary  INSTITUTIONS        MALE       30
# 2    Badin    Urban     Primary  INSTITUTIONS      FEMALE       27
# 3    Badin    Urban     Primary  INSTITUTIONS       MIXED      111
# 4    Badin    Urban     Primary     ENROLMENT       TOTAL   16,446
#
#    Population    No/100000
# 0   1,804,516     9.309976
# 1   1,804,516     1.662496
# 2   1,804,516     1.496246
# 3   1,804,516     6.151234
# 4   1,804,516   911.380115

# %%
df.drop(df[df['Composition'] == "TOTAL"].index, inplace = True)
df.drop(df[df['Location'] == "Total"].index, inplace = True)
df.pop("No/100000")
print(df)
df.head()
# Out:
#                  District Location       School Type        Category  \
# 1                   Badin    Urban           Primary    INSTITUTIONS
# 2                   Badin    Urban           Primary    INSTITUTIONS
# 3                   Badin    Urban           Primary    INSTITUTIONS
# 5                   Badin    Urban           Primary       ENROLMENT
# 6                   Badin    Urban           Primary       ENROLMENT
# ...                   ...      ...               ...             ...
# 3433  Shaheed Benazirabad    Rural  Higher secondary    INSTITUTIONS
# 3435  Shaheed Benazirabad    Rural  Higher secondary       ENROLMENT
# 3436  Shaheed Benazirabad    Rural  Higher secondary       ENROLMENT
# 3438  Shaheed Benazirabad    Rural  Higher secondary  TEACHING STAFF
# 3439  Shaheed Benazirabad    Rural  Higher secondary  TEACHING STAFF
#
#      Composition   Number   Population
# 1           MALE       30    1,804,516
# 2         FEMALE       27    1,804,516
# 3          MIXED      111    1,804,516
# 5           MALE   10,015    1,804,516
# 6         FEMALE    6,431    1,804,516
# ...          ...       ...          ...
# 3433       MIXED        4    1,612,847
# 3435        MALE    6,220    1,612,847
# 3436      FEMALE    1,256    1,612,847
# 3438        MALE       93    1,612,847
# 3439      FEMALE       12    1,612,847
#
# [1624 rows x 7 columns]
#   District Location School Type      Category Composition   Number   \
# 1    Badin    Urban     Primary  INSTITUTIONS        MALE       30
# 2    Badin    Urban     Primary  INSTITUTIONS      FEMALE       27
# 3    Badin    Urban     Primary  INSTITUTIONS       MIXED      111
# 5    Badin    Urban     Primary     ENROLMENT        MALE   10,015
# 6    Badin    Urban     Primary     ENROLMENT      FEMALE    6,431
#
#    Population
# 1   1,804,516
# 2   1,804,516
# 3   1,804,516
# 5   1,804,516
# 6   1,804,516

# %%
df=df.replace(to_replace="MALE",value="1")
df=df.replace(to_replace="FEMALE",value="2")
df=df.replace(to_replace="MIXED",value="3")
# df=df.replace(to_replace="INSTITUTIONS",value="4")
# df=df.replace(to_replace="ENROLMENT",value="5")
# df=df.replace(to_replace="TEACHING STAFF",value="6")
df=df.replace(to_replace="Urban",value="7")
df=df.replace(to_replace="Rural",value="8")
# df=df.replace(to_replace="Badin",value="9")
# df=df.replace(to_replace="Dadu",value="10")
# df=df.replace(to_replace="Hyderabad",value="11")
# df=df.replace(to_replace="Thatta",value="12")
# df=df.replace(to_replace="Jamshoro",value="13")
# df=df.replace(to_replace="Matira",value="14")
# df=df.replace(to_replace="Tando Allah yar",value="15")
# df=df.replace(to_replace="Tando Muhammad Khan",value="16")
# df=df.replace(to_replace="Sujawal",value="17")
# df=df.replace(to_replace="Central Karachi",value="18")
# df=df.replace(to_replace="East Karachi",value="19")
# df=df.replace(to_replace="South Karachi",value="20")
# df=df.replace(to_replace="West Karchi",value="21")
# df=df.replace(to_replace="Malir Karachi",value="22")
# df=df.replace(to_replace="Korangi Karachi",value="23")
# df=df.replace(to_replace="Jacobad",value="24")
# df=df.replace(to_replace="Larkana",value="25")
# df=df.replace(to_replace="Shikarpur",value="26")
# df=df.replace(to_replace="Kashmore",value="27")
# df=df.replace(to_replace="Kamber Shahdadkot",value="28")
# df=df.replace(to_replace="Khairpur Mirs",value="29")
# df=df.replace(to_replace="Sukkhur",value="30")
# df=df.replace(to_replace="Ghotki",value="31")
# df=df.replace(to_replace="Mirpurkhaas",value="32")
# df=df.replace(to_replace="Tharparkar",value="33")
# df=df.replace(to_replace="Umerkot",value="34")
# df=df.replace(to_replace="Sanghar",value="35")
# df=df.replace(to_replace="Naushero Feroz",value="36")
# df=df.replace(to_replace="Shaheed Benazirabad",value="37")
df=df.replace(to_replace="Primary",value="38")
df=df.replace(to_replace="Middle",value="39")
df=df.replace(to_replace="Secondary",value="40")
df=df.replace(to_replace="Higher secondary",value="41")

print(df)
# Out:
#                  District Location School Type        Category Composition  \
# 1                   Badin        7          38    INSTITUTIONS           1
# 2                   Badin        7          38    INSTITUTIONS           2
# 3                   Badin        7          38    INSTITUTIONS           3
# 5                   Badin        7          38       ENROLMENT           1
# 6                   Badin        7          38       ENROLMENT           2
# ...                   ...      ...         ...             ...         ...
# 3433  Shaheed Benazirabad        8          41    INSTITUTIONS           3
# 3435  Shaheed Benazirabad        8          41       ENROLMENT           1
# 3436  Shaheed Benazirabad        8          41       ENROLMENT           2
# 3438  Shaheed Benazirabad        8          41  TEACHING STAFF           1
# 3439  Shaheed Benazirabad        8          41  TEACHING STAFF           2
#
#        Number   Population
# 1          30    1,804,516
# 2          27    1,804,516
# 3         111    1,804,516
# 5      10,015    1,804,516
# 6       6,431    1,804,516
# ...        ...          ...
# 3433        4    1,612,847
# 3435    6,220    1,612,847
# 3436    1,256    1,612,847
# 3438       93    1,612,847
# 3439       12    1,612,847
#
# [1624 rows x 7 columns]

# %%
#df = [["Number","Population"]]
df.head(10)
# Out:
#    District Location School Type        Category Composition   Number   \
# 1     Badin        7          38    INSTITUTIONS           1       30
# 2     Badin        7          38    INSTITUTIONS           2       27
# 3     Badin        7          38    INSTITUTIONS           3      111
# 5     Badin        7          38       ENROLMENT           1   10,015
# 6     Badin        7          38       ENROLMENT           2    6,431
# 8     Badin        7          38  TEACHING STAFF           1      382
# 9     Badin        7          38  TEACHING STAFF           2      168
# 11    Badin        7          39    INSTITUTIONS           1        3
# 12    Badin        7          39    INSTITUTIONS           2        2
# 13    Badin        7          39    INSTITUTIONS           3        5
#
#     Population
# 1    1,804,516
# 2    1,804,516
# 3    1,804,516
# 5    1,804,516
# 6    1,804,516
# 8    1,804,516
# 9    1,804,516
# 11   1,804,516
# 12   1,804,516
# 13   1,804,516

# %%
df.tail(10)
# Out:
#                  District Location School Type        Category Composition  \
# 3426  Shaheed Benazirabad        8          40       ENROLMENT           2
# 3428  Shaheed Benazirabad        8          40  TEACHING STAFF           1
# 3429  Shaheed Benazirabad        8          40  TEACHING STAFF           2
# 3431  Shaheed Benazirabad        8          41    INSTITUTIONS           1
# 3432  Shaheed Benazirabad        8          41    INSTITUTIONS           2
# 3433  Shaheed Benazirabad        8          41    INSTITUTIONS           3
# 3435  Shaheed Benazirabad        8          41       ENROLMENT           1
# 3436  Shaheed Benazirabad        8          41       ENROLMENT           2
# 3438  Shaheed Benazirabad        8          41  TEACHING STAFF           1
# 3439  Shaheed Benazirabad        8          41  TEACHING STAFF           2
#
#       Number   Population
# 3426   7,119    1,612,847
# 3428     540    1,612,847
# 3429     224    1,612,847
# 3431       1    1,612,847
# 3432     -      1,612,847
# 3433       4    1,612,847
# 3435   6,220    1,612,847
# 3436   1,256    1,612,847
# 3438      93    1,612,847
# 3439      12    1,612,847

# %%
df.describe()
# Out:
#        District Location School Type      Category Composition  Number   \
# count      1624     1624        1624          1624        1624     1624
# unique       29        2           4             3           3      764
# top     Jacobad        8          41  INSTITUTIONS           1     -
# freq         56      812         406           696         696      124
#
#         Population
# count          1624
# unique           28
# top      2,404,334
# freq            112

# %%
df.nunique()
# Out:
# District         29
# Location          2
# School Type       4
# Category          3
# Composition       3
#  Number         764
#  Population      28
# dtype: int64

# %%
df.notnull()
# Out:
#       District  Location  School Type  Category  Composition   Number   \
# 1         True      True         True      True         True      True
# 2         True      True         True      True         True      True
# 3         True      True         True      True         True      True
# 5         True      True         True      True         True      True
# 6         True      True         True      True         True      True
# ...        ...       ...          ...       ...          ...       ...
# 3433      True      True         True      True         True      True
# 3435      True      True         True      True         True      True
# 3436      True      True         True      True         True      True
# 3438      True      True         True      True         True      True
# 3439      True      True         True      True         True      True
#
#        Population
# 1             True
# 2             True
# 3             True
# 5             True
# 6             True
# ...            ...
# 3433          True
# 3435          True
# 3436          True
# 3438          True
# 3439          True
#
# [1624 rows x 7 columns]

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
# 13   1,804,516
# 15   1,804,516
# 16   1,804,516
# 18   1,804,516
# 19   1,804,516
# 21   1,804,516
# 22   1,804,516
# 23   1,804,516
# 25   1,804,516
# 26   1,804,516
# 28   1,804,516
# 29   1,804,516
# 31   1,804,516
# 32   1,804,516
# 33   1,804,516
# 35   1,804,516
# 36   1,804,516
# 38   1,804,516
# 39   1,804,516
# 41   1,804,516
# 42   1,804,516
# 43   1,804,516
# 45   1,804,516
# 46   1,804,516
# 48   1,804,516
# 49   1,804,516
# 51   1,804,516
# 52   1,804,516
# 53   1,804,516
# 55   1,804,516
# 56   1,804,516
# 58   1,804,516
# 59   1,804,516
# 61   1,804,516
# 62   1,804,516
# 63   1,804,516
# 65   1,804,516
# 66   1,804,516
# 68   1,804,516
# 69   1,804,516
# 71   1,804,516

# %%
df1.corr()
# Out:
#              Composition
# Composition          1.0

# %%
plt.plot(df['Category'],df['Composition'])
plt.title("Category Vs GenderComposition")
plt.xlabel("Category")
plt.ylabel("GenderComposition")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.bar(df.Category,df.Composition)
plt.show()

# %%
plt.plot(df['Category'],df['Number'])
plt.title("Category Vs GenderComposition")
plt.xlabel("Category")
plt.ylabel("GenderComposition")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-383-a018d390c734> in <module>
# ----> 1 plt.plot(df['Category'],df['Number'])
#       2 plt.title("Category Vs GenderComposition")
#       3 plt.xlabel("Category")
#       4 plt.ylabel("GenderComposition")
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Number'

# %%
df1.corr()
# Out:
#              Composition
# Composition          1.0

# %%
import seaborn as sns

sns.heatmap(df.corr(), vmin=-1, vmax=1,
annot=True,cmap="rocket_r")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:301: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py:301: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
df.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#np.corrcoef(df["Number"], df["Population"])

# %%
#df["Number"].mean()

# %%
import scipy.stats as stats

# %%
df['Composition'].corr(df['Number']

# %%
df.corr()
# Out:
#            No/100000
# No/100000        1.0

# %%
import matplotlib.pyplot as plt

# %%
plt.matshow(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-6d78e98360fd> in <module>
# ----> 1 plt.matshow(df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in matshow(A, fignum, **kwargs)
#    2299         fig = figure(fignum, figsize=figaspect(A))
#    2300         ax = fig.add_axes([0.15, 0.09, 0.775, 0.775])
# -> 2301     im = ax.matshow(A, **kwargs)
#    2302     sci(im)
#    2303     return im
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in matshow(self, Z, **kwargs)
#    7751               'aspect': 'equal',          # (already the imshow default)
#    7752               **kwargs}
# -> 7753         im = self.imshow(Z, **kw)
#    7754         self.title.set_y(1.05)
#    7755         self.xaxis.tick_top()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
#What is correlation test? 
#The strength of the association between two variables is known as correlation test.

# %%
# Composition = {'MALE': 1, 'FEMALE': 2, 'MIXED': 3}
#Composition.df.sindh-education-stats.csv.unique()#
#print(df)

# %%
##Using drop() to delete rows based on column value
#df.drop(df[df['Fee'] >= 24000].index, inplace = True)
